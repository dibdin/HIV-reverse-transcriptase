# %% [markdown]
# <a href="https://colab.research.google.com/github/dibdin/HIV-reverse-transcriptase/blob/code/Part_3_HIV_rtranscriptase_Descriptor_Dataset_Preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Repurposing cheap drugs for HIV**
#
# original code credit: Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In **Part 3**, we will be calculating molecular descriptors that are essentially quantitative description of the compounds in the dataset. Finally, we will be preparing this into a dataset for subsequent model building in Part 4.
#
# ---

# %% [markdown]
# ## **Download PaDEL-Descriptor**

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2021-10-31 03:12:17--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 52.69.186.44
# Connecting to github.com (github.com)|52.69.186.44|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2021-10-31 03:12:17--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M   129MB/s    in 0.2s
#
# 2021-10-31 03:12:20 (129 MB/s) - ‘padel.zip’ saved [25768637/25768637]
#
# ...

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
# ...

# %% [markdown]
# ## **Load bioactivity data**

# %% [markdown]
# Download the curated ChEMBL bioactivity data that has been pre-processed from Parts 1 and 2. Here we will be using the **bioactivity_HIVrtranscriptase_lipinski_pIC50_combined.csv** file that essentially contain the pIC50 values that we will be using for building a regression model.

# %%
! wget https://raw.githubusercontent.com/dibdin/HIV-reverse-transcriptase/main/bioactivity_HIVrtranscriptase_lipinski_pIC50_combined.csv
# Out:
# --2021-10-31 03:12:33--  https://raw.githubusercontent.com/dibdin/HIV-reverse-transcriptase/main/bioactivity_HIVrtranscriptase_lipinski_pIC50_combined.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 971755 (949K) [text/plain]
# Saving to: ‘bioactivity_HIVrtranscriptase_lipinski_pIC50_combined.csv’
#
# bioactivity_HIVrtra 100%[===================>] 948.98K  --.-KB/s    in 0.06s
#
# 2021-10-31 03:12:33 (14.9 MB/s) - ‘bioactivity_HIVrtranscriptase_lipinski_pIC50_combined.csv’ saved [971755/971755]

# %%
import pandas as pd

# %%
df3 = pd.read_csv('bioactivity_HIVrtranscriptase_lipinski_pIC50_combined.csv')

# %%
df3
# Out:
#       Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0              0       CHEMBL296346  ...           4.0  5.000000
# 1              1       CHEMBL318730  ...           3.0  6.339998
# 2              2       CHEMBL303928  ...           4.0  4.000000
# 3              3        CHEMBL68175  ...           3.0  4.493495
# 4              4        CHEMBL69775  ...           3.0  4.899629
# ...          ...                ...  ...           ...       ...
# 7140        9112      CHEMBL4637849  ...           9.0  4.802719
# 7141        9113      CHEMBL4633284  ...           9.0  4.404173
# 7142        9115      CHEMBL4636332  ...           4.0  7.920819
# 7143        9116      CHEMBL4636332  ...           4.0  9.119186
# 7144        9117      CHEMBL4636332  ...           4.0  8.585027
#
# [7145 rows x 9 columns]

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# S=C(NCN1CCOCC1)Nc1ccc(Br)cn1	CHEMBL296346
# CCc1cc(NCc2ccc3ccccc3c2)c(O)nc1C	CHEMBL318730
# O=c1[nH]c2c(c(=O)[nH]1)CNc1ccccc1S2	CHEMBL303928
# C=C(C)CN1Cc2cccc3[nH]c(=O)n(c23)C(C)C1	CHEMBL68175
# C=C(C)CN1Cc2cccc3[nH]c(=O)n(c23)C(C(C)C)C1	CHEMBL69775

# %%
! cat molecule.smi | wc -l
# Out:
# 7145

# %% [markdown]
# ## **Calculate fingerprint descriptors**

# %% [markdown]
# ### **Calculate PaDEL descriptors**

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing CHEMBL305416 in molecule.smi (2195/7145). Average speed: 0.16 s/mol.
# Processing CHEMBL291024 in molecule.smi (2196/7145). Average speed: 0.16 s/mol.
# Processing CHEMBL290781 in molecule.smi (2197/7145). Average speed: 0.16 s/mol.
# Processing CHEMBL151175 in molecule.smi (2198/7145). Average speed: 0.16 s/mol.
# Processing CHEMBL151175 in molecule.smi (2199/7145). Average speed: 0.16 s/mol.
# Processing CHEMBL304615 in molecule.smi (2200/7145). Average speed: 0.16 s/mol.
# Processing CHEMBL288305 in molecule.smi (2201/7145). Average speed: 0.16 s/mol.
# Processing CHEMBL134236 in molecule.smi (2202/7145). Average speed: 0.16 s/mol.
# Processing CHEMBL307162 in molecule.smi (2203/7145). Average speed: 0.16 s/mol.
# Processing CHEMBL306247 in molecule.smi (2205/7145). Average speed: 0.16 s/mol.
# Processing CHEMBL70255 in molecule.smi (2204/7145). Average speed: 0.16 s/mol.
# ...

# %%
! ls -l
# Out:
# total 39008
# -rw-r--r-- 1 root root   971755 Oct 31 03:12 bioactivity_HIVrtranscriptase_lipinski_pIC50_combined.csv
# -rw-r--r-- 1 root root 12707183 Oct 31 03:34 descriptors_output.csv
# drwxr-xr-x 3 root root     4096 Oct 31 03:12 __MACOSX
# -rw-r--r-- 1 root root   465454 Oct 31 03:13 molecule.smi
# drwxrwxr-x 4 root root     4096 May 30  2020 PaDEL-Descriptor
# -rw-r--r-- 1 root root      231 Oct 31 03:12 padel.sh
# -rw-r--r-- 1 root root 25768637 Oct 31 03:12 padel.zip
# drwxr-xr-x 1 root root     4096 Oct 26 13:34 sample_data

# %% [markdown]
# ## **Preparing the X and Y Data Matrices**

# %% [markdown]
# ### **X data matrix**

# %%
df3_X = pd.read_csv('descriptors_output.csv')

# %%
df3_X
# Out:
#                Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0      CHEMBL296346         1.0  ...           0.0           0.0
# 1      CHEMBL303928         1.0  ...           0.0           0.0
# 2       CHEMBL68175         1.0  ...           0.0           0.0
# 3      CHEMBL318730         1.0  ...           0.0           0.0
# 4       CHEMBL69775         1.0  ...           0.0           0.0
# ...             ...         ...  ...           ...           ...
# 7140  CHEMBL4637849         1.0  ...           0.0           0.0
# 7141  CHEMBL4633284         1.0  ...           0.0           0.0
# 7142  CHEMBL4636332         1.0  ...           0.0           0.0
# 7143  CHEMBL4636332         1.0  ...           0.0           0.0
# 7144  CHEMBL4636332         1.0  ...           0.0           0.0
#
# [7145 rows x 882 columns]

# %%
df3_X = df3_X.drop(columns=['Name'])
df3_X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0            1.0         1.0  ...           0.0           0.0
# 1            1.0         1.0  ...           0.0           0.0
# 2            1.0         1.0  ...           0.0           0.0
# 3            1.0         1.0  ...           0.0           0.0
# 4            1.0         1.0  ...           0.0           0.0
# ...          ...         ...  ...           ...           ...
# 7140         1.0         1.0  ...           0.0           0.0
# 7141         1.0         1.0  ...           0.0           0.0
# 7142         1.0         1.0  ...           0.0           0.0
# 7143         1.0         1.0  ...           0.0           0.0
# 7144         1.0         1.0  ...           0.0           0.0
#
# [7145 rows x 881 columns]

# %% [markdown]
# ## **Y variable**

# %% [markdown]
# ### **Convert IC50 to pIC50**

# %%
df3_Y = df3['pIC50']
df3_Y
# Out:
# 0       5.000000
# 1       6.339998
# 2       4.000000
# 3       4.493495
# 4       4.899629
#           ...
# 7140    4.802719
# 7141    4.404173
# 7142    7.920819
# 7143    9.119186
# 7144    8.585027
# Name: pIC50, Length: 7145, dtype: float64

# %% [markdown]
# ## **Combining X and Y variable**

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0            1.0         1.0         0.0  ...           0.0           0.0  5.000000
# 1            1.0         1.0         0.0  ...           0.0           0.0  6.339998
# 2            1.0         1.0         1.0  ...           0.0           0.0  4.000000
# 3            1.0         1.0         1.0  ...           0.0           0.0  4.493495
# 4            1.0         1.0         1.0  ...           0.0           0.0  4.899629
# ...          ...         ...         ...  ...           ...           ...       ...
# 7140         1.0         1.0         1.0  ...           0.0           0.0  4.802719
# 7141         1.0         1.0         1.0  ...           0.0           0.0  4.404173
# 7142         1.0         1.0         0.0  ...           0.0           0.0  7.920819
# 7143         1.0         1.0         0.0  ...           0.0           0.0  9.119186
# ...

# %%
dataset3.to_csv('bioactivity_data_HIVrtranscriptase_combined_pubchem_fp.csv', index=False)

# %% [markdown]
# # **Let's download the CSV file to your local computer for the Part 3B (Model Building).**

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! cp bioactivity_data_HIVrtranscriptase_combined_pubchem_fp.csv "/content/gdrive/My Drive/Colab Notebooks/dataHIVrtranscriptase"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/dataHIVrtranscriptase"
# Out:
# bioactivity_data_HIVrtranscriptase_combined_pubchem_fp.csv
# bioactivity_data_HIVrtranscriptase.csv
# bioactivity_HIVrtranscriptase_lipinski_pIC50_combined.csv
# bioactivity_preprocessed_data_HIVrtranscriptase.csv
